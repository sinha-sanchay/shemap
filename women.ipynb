# %%
import pandas as pd

df = pd.read_csv('districtwise-crime-against-women-2017-onwards.csv')

print("Shape:", df.shape)
df.head()
# Out:
# Shape: (5322, 49)
#    id  year      state_name  state_code  district_name  district_code  \
# 0   0  2017  Andhra Pradesh          28  Ananthapuramu            502
# 1   1  2017  Andhra Pradesh          28       Chittoor            503
# 2   2  2017  Andhra Pradesh          28         Y.S.R.            504
# 3   3  2017  Andhra Pradesh          28  East Godavari            505
# 4   4  2017  Andhra Pradesh          28  Ananthapuramu            502
#
#   registration_circles  murder_with_rape_gang_rape  dowry_deaths  \
# 0            Anantapur                         0.0          14.0
# 1             Chittoor                         0.0           8.0
# 2             Cuddapah                         0.0          15.0
# 3        East Godavari                         0.0          10.0
# 4     Guntakal Railway                         0.0           3.0
#
#    abetment_to_suicide_of_women  ...  \
# 0                          55.0  ...
# 1                          24.0  ...
# ...

# %%
df['district_name_clean'] = df['district_name'].str.strip().str.lower()

print("Sample districts:", df['district_name_clean'].unique()[:20])

print("\nMissing values per column:")
print(df[['district_name', 'year']].isnull().sum())

print("\nYears in data:", df['year'].unique())
# Out:
# Sample districts: ['ananthapuramu' 'chittoor' 'y.s.r.' 'east godavari' 'guntur' 'krishna'
#  'kurnool' 'sri potti sriramulu nellore' 'prakasam' 'srikakulam'
#  'tirupati' 'ntr' 'visakhapatnam' 'vizianagaram' 'west godavari' 'anjaw'
#  'changlang' 'papum pare' 'dibang valley' 'east kameng']
#
# Missing values per column:
# district_name    0
# year             0
# dtype: int64
#
# Years in data: [2017 2018 2019 2020 2021 2022]
